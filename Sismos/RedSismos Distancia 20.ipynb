# %% [markdown]
# # Analisis de Datos: Sismos Distancia 20

# %%
import sys 
sys.path.append('..')

from framework import Framework
import pandas as pd

# %%
df = pd.read_csv('Datasets/dataset20.csv')
df
# Out:
#          0     1     2     3     4     5
# 0     6225  6225  6951  1909  9076  7433
# 1     6225  6951  1909  9076  7433  4411
# 2     6951  1909  9076  7433  4411  3919
# 3     1909  9076  7433  4411  3919  6226
# 4     9076  7433  4411  3919  6226   884
# ...    ...   ...   ...   ...   ...   ...
# 4884  5275  3645  6225  6611  4578  6414
# 4885  3645  6225  6611  4578  6414  1830
# 4886  6225  6611  4578  6414  1830  6481
# 4887  6611  4578  6414  1830  6481  6481
# 4888  4578  6414  1830  6481  6481  5342
#
# [4889 rows x 6 columns]

# %%
fw = Framework(
    dataframe  = df,
    inputs     = ['{}'.format(i) for i in range(5)],
    target     = '5',
    save_dir   = "Modelos",
    test_size  = 0.15,
    random_state=0
)
hidden_layers = (5,200,150,100,50)
max_iter = 150

svm_model = "svm_distancia_20"
mlp_model = "mlp_distancia_20"
sequential_model = "sequential_distancia_20"

fw.load_svm_model(svm_model)
fw.load_mlp_model(mlp_model)
fw.load_sequential_model(sequential_model)

# %%
#fw.get_svm_model()
print("SVM RMSE:",fw.get_svm_rmse())
# Out:
# SVM RMSE: (2477.4837734097196, 2246.689150181251)

# %%
#fw.save_svm_model('svm_distancia_20')

# %%
#fw.get_mlp_model(hidden_layers=hidden_layers,max_iter=max_iter)
print("MLP RMSE:",fw.get_mlp_rmse())
# Out:
# MLP RMSE: (2386.6595389264116, 2205.3572390614663)

# %%
#fw.save_mlp_model('mlp_distancia_20')

# %%
#fw.get_sequential_model(hidden_layers=hidden_layers, epochs=max_iter)
print("Sequential RMSE:",fw.get_sequential_rmse())
# Out:
# Sequential RMSE: (2367.1881567939563, 2195.2434823609524)

# %%
#fw.save_sequential_model('sequential_distancia_20')

# %%
fw.plot_compare_nodes(
    'Graficas/modelos_distancia20.png',
    start_offset = 5,
    end_offset   = 4894,
    x_label="Nodos Salida",
    y_label="Nodos Llegada",
    figsize=(20,9),
    title_fontsize = 22,
    label_fontsize = 20,
    legend_fontsize = 20,
    ticks_fontsize = 18,
)

# %%
fw.plot_grid_nodes(
    20,
    'Graficas/grid_distancia20.png',
    figsize=(10,30),
    alphaData=0.1,
    alpha=0.09,
    dpi=480,
    linewidth=0.6
)
# Out:
# 9483

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# from matplotlib.patches import Rectangle
# from math import sqrt

# fig, ax = plt.subplots(figsize=(20,20))
# #ax.imshow(data, cmap=cmap, norm=norm)

# min_val = min(fw.y_values)
# max_val = max(fw.y_values)
# print(max_val)
# #print(sqrt(max_val))
# rows = cols = int(sqrt(max_val))

# vals_xy = ((max_val+1)//cols, (max_val+1)//rows)
# print(vals_xy)
# for i in range(3):
#     # draw gridlines
#     ax.grid(which='major', axis='both', linestyle='-', color='k', linewidth=0.05)
#     ax.set_xticks(np.arange(0,vals_xy[0]+10, 1));
#     ax.set_yticks(np.arange(0,vals_xy[1]+10, 1));
#     for value in fw.y_values:
#         xy = ((value-1)%cols,rows-((value-1)//rows))
#         #print(xy)
#         rectangle = Rectangle(xy, 1, 1,alpha=0.1, facecolor='k')
#         ax.add_patch(rectangle)
#         ax.text(xy[0],xy[1],str(value), fontsize=3)
        
# plt.tight_layout()
# plt.show()

# %%
# fig.savefig('Graficas/datos_20.png', dpi=240)
